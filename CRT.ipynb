# %% [markdown]
# <a href="https://colab.research.google.com/github/pushpa0606/python/blob/main/CRT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=4

for i in range (n):
  for j in range(0,n):
    if j <=i:
      print("*", end="")
    else:
      print(" ", end="")
# Out:
# *   **  *** ****

# %%
n = 4

for i in range(n):
    for j in range(0, n):
        if j <=i:
            print("*", end="")
        else:
            print(" ", end="")
    print()
# Out:
# *
# **
# ***
# ****

# %%
n = 4
num=1
for i in range(n):
    for j in range(n):
        if j <= i:
            print("1", end="")
        else:
            print("", end="")
    print()
# Out:
# 1
# 11
# 111
# 1111

# %%
n = 4

for i in range(n):
    for j in range(0, n):
        if j >= i:
            print("*", end="")
        else:
            print(" ", end="")
    print()
# Out:
# ****
#  ***
#   **
#    *

# %%
n = 4

for i in range(n):
    for j in range(0, n):
        if j >= i:
            print("* ", end="")
        else:
            print(" ", end="")
    print()
# Out:
# * * * *
#  * * *
#   * *
#    *

# %%
n = 10

for i in range(n):
    for j in range(0, n):
        if j >= i:
            print("* ", end="")
        else:
            print(" ", end="")
    print()
# Out:
# * * * * * * * * * *
#  * * * * * * * * *
#   * * * * * * * *
#    * * * * * * *
#     * * * * * *
#      * * * * *
#       * * * *
#        * * *
#         * *
#          *

# %%
n = 5

for i in range(n):
    for j in range(0, n):
        if j >=n-1-i:
            print("* ", end="")
        else:
            print(" ", end="")

    print()
# Out:
#     *
#    * *
#   * * *
#  * * * *
# * * * * *

# %%
n = 5

for i in range(n):
    for j in range(0, n):
        if j >=n-1-i:
            print(" * ", end="")
        else:
            print(" ", end="")
    print()
# Out:
#      *
#     *  *
#    *  *  *
#   *  *  *  *
#  *  *  *  *  *

# %%
n = 5

for i in range(n):
    for j in range(0, n):
        if j >=n-1-i:
            print("*", end="")
        else:
            print("* ", end="")
    print()
# Out:
# * * * * *
# * * * **
# * * ***
# * ****
# *****

# %%
n = 5

for i in range(n):
    for j in range(0, n):
        if j >=n-1-i:
            print("* ", end="")
        else:
            print(" ", end="")
    print()

# %%
n = 5

for i in range(1, n + 1):
    for j in range(n):
            print(i, end="")
    print()
# Out:
# 11111
# 22222
# 33333
# 44444
# 55555

# %%
n = 5

for i in range(1, n + 1):
    for j in range(i):
        if j % 2 ==0:
            print(1, end="")
        else:
            print(0, end="")
    print()
# Out:
# 1
# 10
# 101
# 1010
# 10101

# %%
n = 4

for i in range(n):
    for j in range(i +1):
      print(i + j, end=" ")
    print()
# Out:
# 0
# 1 2
# 2 3 4
# 3 4 5 6

# %%
n = 5

for i in range(n):
    for j in range(0, n):
        if j >=n-1-i:
            print("* ", end="")
        else:
            print(" ", end="")

    for j in range(0, n):
        if j <= i:
            print("* ", end="")
        else:
            print(" ", end="")
    print()
for i in range(1,n):
    for j in range(0, n):
        if j >=i:
            print("* ", end="")
        else:
            print(" ", end="")

    for j in range(0, n):
        if j < n-i:
            print("* ", end="")
        else:
            print(" ", end="")
    print()
# Out:
#     * *
#    * * * *
#   * * * * * *
#  * * * * * * * *
# * * * * * * * * * *
#  * * * * * * * *
#   * * * * * *
#    * * * *
#     * *
